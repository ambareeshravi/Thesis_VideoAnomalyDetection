# %%
import sys
sys.path.append("..")

# %%
from train_autoencoder import *
from test_autoencoder import *

# %%
from C2D_Models import *

# %%
models = [
    C2D_AE_128_3x3(channels = 1),
    C2D_AE_128_3x3(channels = 1),
    C2D_AE_128_3x3(channels = 1),
         ]

model_names = [
    "C2D_3x3_L2_MSE",
    "C2D_3x3_L2_WEIGHTED",
    "C2D_3x3_L2_QUALITY",
]

model_names = [join_paths(["C2D_AE_models/128/losses/", mn+"_UCSD2"]) for mn in model_names]

# %% [markdown]
# # Training

# %%
optimizers = [ADAM(m) for m in models]
losses = [MSE_LOSS(), WEIGHTED_SIMILARITY(), QUALITY_LOSS()]

# %%
train_data = UCSD(2)
# Out:
# 16it [00:02,  6.86it/s]

# %%
train_loader, val_loader = get_data_loaders(train_data, batch_size=48)

# %%
trainer = AutoEncoder_Trainer(
    models,
    model_names,
    train_loader, 
    val_loader,
    optimizers,
    losses,
    epochs = 300
)

# %%
trainer.train()
# Out:
# Estimated Time 3.28 hours | Will be completed by 2020-11-19 03:39:
# ------------------------------------------------------------
# Epoch: [001/300] | time/epoch: 39.46 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#                 Loss
# Training    0.015721
# Validation  0.036098
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#                 Loss
# Training    0.081449
# Validation  0.075173
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#                 Loss
# Training    0.789855
# Validation  0.801986
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [002/300] | time/epoch: 40.26 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#                Loss
# Training    0.00454
# Validation  0.00473
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#                 Loss
# Training    0.026129
# Validation  0.021567
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#                Loss
# Training    0.75306
# Validation  0.74035
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [003/300] | time/epoch: 39.91 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2  Loss -1    Loss *
# Training    0.015721  0.00454  0.003272
# Validation  0.036098  0.00473  0.003346
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.081449  0.026129  0.018109
# Validation  0.075173  0.021567  0.015379
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#              Loss -2  Loss -1    Loss *
# Training    0.789855  0.75306  0.738673
# Validation  0.801986  0.74035  0.747906
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [004/300] | time/epoch: 39.84 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#             Loss -2   Loss -1    Loss *
# Training    0.00454  0.003272  0.002542
# Validation  0.00473  0.003346  0.002360
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.026129  0.018109  0.013344
# Validation  0.021567  0.015379  0.011055
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#             Loss -2   Loss -1    Loss *
# Training    0.75306  0.738673  0.731423
# Validation  0.74035  0.747906  0.730265
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [005/300] | time/epoch: 42.87 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.003272  0.002542  0.002037
# Validation  0.003346  0.002360  0.002033
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.018109  0.013344  0.010541
# Validation  0.015379  0.011055  0.009062
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.738673  0.731423  0.727053
# Validation  0.747906  0.730265  0.726929
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [006/300] | time/epoch: 40.18 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.002542  0.002037  0.001702
# Validation  0.002360  0.002033  0.001819
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.013344  0.010541  0.008552
# Validation  0.011055  0.009062  0.008054
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.731423  0.727053  0.723756
# Validation  0.730265  0.726929  0.722935
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [007/300] | time/epoch: 40.07 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.002037  0.001702  0.001506
# Validation  0.002033  0.001819  0.001716
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.010541  0.008552  0.007581
# Validation  0.009062  0.008054  0.007060
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.727053  0.723756  0.720674
# Validation  0.726929  0.722935  0.719705
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [008/300] | time/epoch: 39.77 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.001702  0.001506  0.001347
# Validation  0.001819  0.001716  0.001819
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.008552  0.007581  0.006761
# Validation  0.008054  0.007060  0.006724
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.723756  0.720674  0.717722
# Validation  0.722935  0.719705  0.718901
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [009/300] | time/epoch: 39.97 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.001506  0.001347  0.001283
# Validation  0.001716  0.001819  0.001974
# ----------------------------------------
# Model: C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0
2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2',
#  'C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2',
#  'C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2']

# %%
for ae_model in trainer.autoencoder_models:
    save_model(ae_model.model, ae_model.model_file)

# %%
print("Training done")
# Out:
# Training done

# %% [markdown]
# # Testing

# %%
test_data = UCSD(2, isTrain=False, sample_stride = 1)
# Out:
# 12it [00:01,  6.70it/s]

# %%
for ae_model in trainer.autoencoder_models:
    print("-"*40)
    print(ae_model.model_file)
    tester = AutoEncoder_Tester(
        ae_model.model,
        test_data,
    )
    results = tester.test(save_as = ".pkl".join(ae_model.model_file.split(".pth.tar")))
    print("="*40)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
# 7it [00:14,  2.09s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:16,  2.11s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:18,  1.92s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:19,  1.89s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:24,  2.02s/it]
# 0it [00:00, ?it/s]
# AUC-ROC Score of  OneClassSVM: 0.4905512504402959
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.9097663314616488
# squared_ROC_AUC_Score :
#  0.8344271612992273
# aggregated_absolute_ROC_AUC_Score :
#  0.6601056710109193
# aggregated_square_ROC_AUC_Score :
#  0.6567312433955618
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.49      0.62      1670
#            1       0.17      0.51      0.26       340
#
#     accuracy                           0.50      2010
#    macro avg       0.50      0.50      0.44      2010
# weighted avg       0.72      0.50      0.56      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.49      0.62      1670
#            1       0.17      0.51      0.26       340
#
#     accuracy                           0.50      2010
#    macro avg       0.50      0.50      0.44      2010
# weighted avg       0.72      0.50      0.56      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
# 7it [00:14,  2.07s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:16,  2.09s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:18,  1.91s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:19,  1.88s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:24,  2.00s/it]
# 0it [00:00, ?it/s]
# AUC-ROC Score of  OneClassSVM: 0.454579077139838
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.910478149832362
# squared_ROC_AUC_Score :
#  0.8533072847160624
# aggregated_absolute_ROC_AUC_Score :
#  0.6648555829517435
# aggregated_square_ROC_AUC_Score :
#  0.6745861218738993
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.48      0.61      1670
#            1       0.18      0.56      0.27       340
#
#     accuracy                           0.49      2010
#    macro avg       0.51      0.52      0.44      2010
# weighted avg       0.73      0.49      0.55      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.48      0.61      1670
#            1       0.18      0.56      0.27       340
#
#     accuracy                           0.49      2010
#    macro avg       0.51      0.52      0.44      2010
# weighted avg       0.73      0.49      0.55      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
# 7it [00:14,  2.07s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:16,  2.09s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:17,  1.90s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:19,  1.87s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:24,  2.00s/it]
# AUC-ROC Score of  OneClassSVM: 0.46489961253962664
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.8983961823037869
# squared_ROC_AUC_Score :
#  0.8310575548030954
# aggregated_absolute_ROC_AUC_Score :
#  0.6628443113772455
# aggregated_square_ROC_AUC_Score :
#  0.6652377597745684
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.48      0.61      1670
#            1       0.19      0.59      0.28       340
#
#     accuracy                           0.50      2010
#    macro avg       0.52      0.53      0.45      2010
# weighted avg       0.74      0.50      0.56      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.48      0.61      1670
#            1       0.19      0.59      0.28       340
#
#     accuracy                           0.50      2010
#    macro avg       0.52      0.53      0.45      2010
# weighted avg       0.74      0.50      0.56      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================

# %%
try:
    del test_data
except:
    pass
test_data = UCSD(2, isTrain=False, sample_stride = 1, useCorrectedAnnotations = False)
# Out:
# 12it [00:01,  6.86it/s]

# %%
for ae_model in trainer.autoencoder_models:
    print("-"*40)
    print(ae_model.model_file)
    tester = AutoEncoder_Tester(
        ae_model.model,
        test_data,
    )
    results = tester.test(save_as = ".pkl".join(ae_model.model_file.split(".pth.tar")))
    print("="*40)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_MSE_UCSD2/C2D_3x3_L2_MSE_UCSD2.pth.tar
# 7it [00:14,  2.09s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:16,  2.11s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:18,  1.92s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:19,  1.89s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:24,  2.02s/it]
# 0it [00:00, ?it/s]
# AUC-ROC Score of  OneClassSVM: 0.5078162715228236
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.9115595128521415
# squared_ROC_AUC_Score :
#  0.8355337857363787
# aggregated_absolute_ROC_AUC_Score :
#  0.6900210534785174
# aggregated_square_ROC_AUC_Score :
#  0.6815376414740117
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.50      0.63      1648
#            1       0.19      0.55      0.29       362
#
#     accuracy                           0.51      2010
#    macro avg       0.51      0.52      0.46      2010
# weighted avg       0.72      0.51      0.56      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.50      0.63      1648
#            1       0.19      0.55      0.29       362
#
#     accuracy                           0.51      2010
#    macro avg       0.51      0.52      0.46      2010
# weighted avg       0.72      0.51      0.56      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_WEIGHTED_UCSD2/C2D_3x3_L2_WEIGHTED_UCSD2.pth.tar
# 7it [00:14,  2.08s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:16,  2.10s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:18,  1.92s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:19,  1.88s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:24,  2.01s/it]
# 0it [00:00, ?it/s]
# AUC-ROC Score of  OneClassSVM: 0.4736529796706539
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.9180170234273215
# squared_ROC_AUC_Score :
#  0.8594910184176604
# aggregated_absolute_ROC_AUC_Score :
#  0.6954453414150084
# aggregated_square_ROC_AUC_Score :
#  0.6997364962720592
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.49      0.62      1648
#            1       0.20      0.59      0.30       362
#
#     accuracy                           0.51      2010
#    macro avg       0.52      0.54      0.46      2010
# weighted avg       0.73      0.51      0.56      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.49      0.62      1648
#            1       0.20      0.59      0.30       362
#
#     accuracy                           0.51      2010
#    macro avg       0.52      0.54      0.46      2010
# weighted avg       0.73      0.51      0.56      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================
# ----------------------------------------
# C2D_AE_models/128/losses/C2D_3x3_L2_QUALITY_UCSD2/C2D_3x3_L2_QUALITY_UCSD2.pth.tar
# 7it [00:15,  2.19s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:17,  2.21s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:18,  2.00s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:20,  1.98s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:25,  2.11s/it]
# AUC-ROC Score of  OneClassSVM: 0.47840342219599846
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.9060862685773596
# squared_ROC_AUC_Score :
#  0.8368197347735534
# aggregated_absolute_ROC_AUC_Score :
#  0.6944295446011908
# aggregated_square_ROC_AUC_Score :
#  0.6911843587405461
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.49      0.62      1648
#            1       0.21      0.61      0.31       362
#
#     accuracy                           0.51      2010
#    macro avg       0.53      0.55      0.46      2010
# weighted avg       0.74      0.51      0.56      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.49      0.62      1648
#            1       0.21      0.61      0.31       362
#
#     accuracy                           0.51      2010
#    macro avg       0.53      0.55      0.46      2010
# weighted avg       0.74      0.51      0.56      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================

# %%
exit()
