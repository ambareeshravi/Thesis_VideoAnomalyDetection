# %%
import sys
sys.path.append("..")

# %%
from train_autoencoder import *
from test_autoencoder import *

# %%
from C2D_Models import *
from PatchWise.models_PatchWise import *

# %%
models = [
    PatchWise_C2D(channels = 1)
         ]

model_names = [
    "C2D_3x3_Patch_2xE",
]

model_names = [join_paths(["C2D_AE_models/128/patched/", mn+"_MSE_UCSD2"]) for mn in model_names]

# %% [markdown]
# # Training

# %%
optimizers = [ADAM(m) for m in models]
losses = [MSE_LOSS() for m in models]

# %%
train_data = UCSD(2)
# Out:
# 16it [00:02,  7.26it/s]

# %%
train_loader, val_loader = get_data_loaders(train_data, batch_size=64)

# %%
trainer = AutoEncoder_Trainer(
    models,
    model_names,
    train_loader, 
    val_loader,
    optimizers,
    losses,
    epochs = 300
)

# %%
trainer.train()
# Out:
# Estimated Time 2.32 hours | Will be completed by 2020-11-17 11:26:
# ------------------------------------------------------------
# Epoch: [001/200] | time/epoch: 41.88 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#                 Loss
# Training    0.111519
# Validation  0.091136
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [002/200] | time/epoch: 41.99 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#                 Loss
# Training    0.069844
# Validation  0.062196
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [003/200] | time/epoch: 42.27 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.111519  0.069844  0.057432
# Validation  0.091136  0.062196  0.050755
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [004/200] | time/epoch: 42.46 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.069844  0.057432  0.047783
# Validation  0.062196  0.050755  0.044111
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [005/200] | time/epoch: 42.53 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.057432  0.047783  0.039071
# Validation  0.050755  0.044111  0.037605
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [006/200] | time/epoch: 42.50 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.047783  0.039071  0.033795
# Validation  0.044111  0.037605  0.033010
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [007/200] | time/epoch: 42.57 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.039071  0.033795  0.031969
# Validation  0.037605  0.033010  0.031684
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [008/200] | time/epoch: 42.58 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.033795  0.031969  0.031356
# Validation  0.033010  0.031684  0.031196
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [009/200] | time/epoch: 42.74 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1   Loss *
# Training    0.031969  0.031356  0.03109
# Validation  0.031684  0.031196  0.03098
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [010/200] | time/epoch: 42.76 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2  Loss -1    Loss *
# Training    0.031356  0.03109  0.030801
# Validation  0.031196  0.03098  0.030768
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [011/200] | time/epoch: 42.70 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#             Loss -2   Loss -1    Loss *
# Training    0.03109  0.030801  0.030595
# Validation  0.03098  0.030768  0.030384
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [012/200] | time/epoch: 42.72 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.030801  0.030595  0.030391
# Validation  0.030768  0.030384  0.030223
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [013/200] | time/epoch: 42.71 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.030595  0.030391  0.030164
# Validation  0.030384  0.030223  0.030026
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [014/200] | time/epoch: 42.75 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.030391  0.030164  0.030013
# Validation  0.030223  0.030026  0.029774
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [015/200] | time/epoch: 42.82 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.030164  0.030013  0.024072
# Validation  0.030026  0.029774  0.020504
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [016/200] | time/epoch: 42.80 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.030013  0.024072  0.019582
# Validation  0.029774  0.020504  0.019412
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [017/200] | time/epoch: 42.86 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.024072  0.019582  0.019184
# Validation  0.020504  0.019412  0.019270
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [018/200] | time/epoch: 42.79 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.019582  0.019184  0.018991
# Validation  0.019412  0.019270  0.018901
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [019/200] | time/epoch: 42.79 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.019184  0.018991  0.018813
# Validation  0.019270  0.018901  0.018879
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [020/200] | time/epoch: 42.81 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.018991  0.018813  0.017650
# Validation  0.018901  0.018879  0.015328
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [021/200] | time/epoch: 42.77 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.018813  0.017650  0.014074
# Validation  0.018879  0.015328  0.013586
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [022/200] | time/epoch: 42.82 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.017650  0.014074  0.013233
# Validation  0.015328  0.013586  0.013288
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [023/200] | time/epoch: 42.79 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.014074  0.013233  0.013036
# Validation  0.013586  0.013288  0.013231
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [024/200] | time/epoch: 42.84 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.013233  0.013036  0.012165
# Validation  0.013288  0.013231  0.010577
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [025/200] | time/epoch: 42.82 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.013036  0.012165  0.009162
# Validation  0.013231  0.010577  0.008933
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [026/200] | time/epoch: 42.81 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.012165  0.009162  0.008575
# Validation  0.010577  0.008933  0.008425
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [027/200] | time/epoch: 42.87 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.009162  0.008575  0.007787
# Validation  0.008933  0.008425  0.007134
# ----------------------------------------
# ------------------------------------------------------------
# Epoch:
seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.001347  0.001173  0.001070
# Validation  0.001140  0.001006  0.000952
# ----------------------------------------
# ------------------------------------------------------------
# Epoch: [200/200] | time/epoch: 42.81 seconds
# ------------------------------------------------------------
# Model: C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
#              Loss -2   Loss -1    Loss *
# Training    0.001173  0.001070  0.001004
# Validation  0.001006  0.000952  0.000894
# ----------------------------------------
# 'val_loss'
# Could not clear the memory. Kill the process manually.
# name 'gc' is not defined
# ['C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2']

# %%
for ae_model in trainer.autoencoder_models:
    save_model(ae_model.model, ae_model.model_file)

# %%
print("Training done")
# Out:
# Training done

# %% [markdown]
# # Testing

# %%
test_data = UCSD(2, isTrain=False, sample_stride = 1)
# Out:
# 12it [00:01,  6.64it/s]

# %%
for ae_model in trainer.autoencoder_models:
    print("-"*40)
    print(ae_model.model_file)
    tester = AutoEncoder_Tester(
        ae_model.model,
        test_data,
        patchwise = True
    )
    results = tester.test(save_as = ".pkl".join(ae_model.model_file.split(".pth.tar")))
    print("="*40)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
# 7it [00:16,  2.44s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:19,  2.47s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:21,  2.24s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:23,  2.22s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:28,  2.36s/it]
# AUC-ROC Score of  OneClassSVM: 0.5265498414934836
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.8652353325120221
# squared_ROC_AUC_Score :
#  0.8603657696106619
# aggregated_absolute_ROC_AUC_Score :
#  0.6543976752377598
# aggregated_square_ROC_AUC_Score :
#  0.6811236350827756
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.45      0.59      1670
#            1       0.20      0.66      0.30       340
#
#     accuracy                           0.49      2010
#    macro avg       0.53      0.55      0.45      2010
# weighted avg       0.75      0.49      0.54      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.45      0.59      1670
#            1       0.20      0.66      0.30       340
#
#     accuracy                           0.49      2010
#    macro avg       0.53      0.55      0.45      2010
# weighted avg       0.75      0.49      0.54      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================

# %%
# del test_data
test_data = UCSD(2, isTrain=False, sample_stride = 1, useCorrectedAnnotations = False)
# Out:
# 12it [00:01,  6.89it/s]

# %%
for ae_model in trainer.autoencoder_models:
    print("-"*40)
    print(ae_model.model_file)
    tester = AutoEncoder_Tester(
        ae_model.model,
        test_data,
        patchwise = True
    )
    results = tester.test(save_as = ".pkl".join(ae_model.model_file.split(".pth.tar")))
    print("="*40)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# C2D_AE_models/128/patched/C2D_3x3_Patch_2xE_MSE_UCSD2/C2D_3x3_Patch_2xE_MSE_UCSD2.pth.tar
# 7it [00:17,  2.46s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 8it [00:19,  2.48s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 9it [00:21,  2.27s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 10it [00:23,  2.24s/it]
# Abs ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# Sqr ROC-AUC: Only one class present in y_true. ROC AUC score is not defined in that case.
# 12it [00:28,  2.38s/it]
# AUC-ROC Score of  OneClassSVM: 0.5404307246687765
# -------------------- TEST RESULTS --------------------
# absolute_ROC_AUC_Score :
#  0.8657336809950587
# squared_ROC_AUC_Score :
#  0.8614601850562724
# aggregated_absolute_ROC_AUC_Score :
#  0.6808839108512579
# aggregated_square_ROC_AUC_Score :
#  0.699917529367591
# abs_report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.46      0.60      1648
#            1       0.22      0.68      0.33       362
#
#     accuracy                           0.50      2010
#    macro avg       0.54      0.57      0.46      2010
# weighted avg       0.75      0.50      0.55      2010
#
# sqr_report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.46      0.60      1648
#            1       0.22      0.68      0.33       362
#
#     accuracy                           0.50      2010
#    macro avg       0.54      0.57      0.46      2010
# weighted avg       0.75      0.50      0.55      2010
#
# -------------------- TEST RESULTS --------------------
# ========================================

# %%
exit()
